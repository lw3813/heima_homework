# %%
# 部门：EPG
# 工号：11812
# 姓名：柳伟
# L5 作业 购物篮词云展示

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from lxml import etree
from nltk.tokenize import word_tokenize
import numpy as np

# %%
# 数据加载
df = pd.read_csv('./Market_Basket_Optimisation.csv')

# %%
df.shape
# Out:
# (7500, 20)

# %%
# 读取字段
word = ''
for i in range(7500):
    for j in range(20):
        if str(df.iloc[i,j]) != 'nan':
            word = word + ' ' + str(df.iloc[i,j])

# %%
# 读取购物篮图片
image = np.array(Image.open('market_basket.png'))

# %%
# 去掉停用词
def remove_stop_words(f):
    stop_words = ['low fat']
    for stop_word in stop_words:
        f = f.replace(stop_word,'')
    return f

# %%
remove_stop_words(word)
# Out:
# ' burgers meatballs eggs chutney turkey avocado mineral water milk energy bar whole wheat rice green tea  yogurt whole wheat pasta french fries soup light cream shallot frozen vegetables spaghetti green tea french fries eggs pet food cookies turkey burgers mineral water eggs cooking oil spaghetti champagne cookies mineral water salmon mineral water shrimp chocolate chicken honey oil cooking oil  yogurt turkey eggs turkey fresh tuna tomatoes spaghetti mineral water black tea salmon eggs chicken extra dark chocolate meatballs milk honey french fries protein bar red wine shrimp pasta pepper eggs chocolate shampoo rice sparkling water spaghetti mineral water ham body spray pancakes green tea burgers grated cheese shrimp pasta avocado honey white wine toothpaste eggs parmesan cheese spaghetti soup avocado milk fresh bread ground beef spaghetti mineral water milk energy bar black tea salmon frozen smoothie escalope sparkling water mineral water eggs chicken chocolate french fries frozen ve
# ...

# %%
# 生成词云
wc = WordCloud(
    background_color="white",
    font_path="C:/Windows/Fonts/STKAITI.TTF",
    max_font_size=100,
    max_words=300,
    mask = image
).generate(word)
plt.figure(figsize=(10,10))
image_color = ImageColorGenerator(image)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
plt.show()
wc.to_file("购物篮词云.jpg")

# %%
# 生成词云,展示最多的十个商品
wc = WordCloud(
    background_color="white",
    font_path="C:/Windows/Fonts/STKAITI.TTF",
    max_font_size=100,
    max_words=10,
    mask = image
).generate(word)
plt.figure(figsize=(10,10))
image_color = ImageColorGenerator(image)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
plt.show()
wc.to_file("购物篮词云.jpg")
